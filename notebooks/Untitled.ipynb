# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\Users\Vishal\Desktop\AirPressureFailureDetection\data_given\training_data\apsfailure_20220830_183412.csv")
df1
# Out:
#      class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001  \
# 0      neg   76698     na  2130706438    280      0      0      0      0
# 1      neg   33058     na           0     na      0      0      0      0
# 2      neg   41040     na         228    100      0      0      0      0
# 3      neg      12      0          70     66      0     10      0      0
# 4      neg   60874     na        1368    458      0      0      0      0
# ...    ...     ...    ...         ...    ...    ...    ...    ...    ...
# 2995   neg    1132      8         188     46      0      0      0      0
# 2996   neg    1974     na          62     54      0      0      0      0
# 2997   neg   41054     na         584    490      0      0      0      0
# 2998   neg   49754     na  2130706432   2818      0      0      0      0
# 2999   neg   64178     na         312    260      0      0      0      0
#
#      ag_002  ...   ee_002  ee_003  ee_004  ee_005  ee_006   ee_007  ee_008  \
# ...

# %%
df2 = pd.read_csv(r"C:\Users\Vishal\Desktop\AirPressureFailureDetection\data_given\training_data\apsfailure_20220830_183422.csv")
df2
# Out:
#      class  aa_000 ab_000 ac_000 ad_000 ae_000 af_000 ag_000 ag_001 ag_002  \
# 0      neg    2072     na     66     46      0      0      0      0     92
# 1      neg   42960     na    142    126      0      0      0      0      0
# 2      neg   31608     na   3950   3186      0      0      0      0      0
# 3      neg   42756     na      0     na      0      0      0      0      0
# 4      neg   60572     na   2370   2110      0      0      0      0      0
# ...    ...     ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2995   neg   38258      0      0    106      0      0      0      0      0
# 2996   neg   30606     na    326    226      0      0      0      0      0
# 2997   neg     516     na     32     22      0      0      0      0  10710
# 2998   neg    2256     na     48     38      0      0      0      0      0
# 2999   neg   30800     na      0     na      0      0      0      0      0
#
# ...

# %%
frames = [df1, df2]
df_merged = pd.concat(frames)
df_merged
# Out:
#      class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001  \
# 0      neg   76698     na  2130706438    280      0      0      0      0
# 1      neg   33058     na           0     na      0      0      0      0
# 2      neg   41040     na         228    100      0      0      0      0
# 3      neg      12      0          70     66      0     10      0      0
# 4      neg   60874     na        1368    458      0      0      0      0
# ...    ...     ...    ...         ...    ...    ...    ...    ...    ...
# 2995   neg   38258      0           0    106      0      0      0      0
# 2996   neg   30606     na         326    226      0      0      0      0
# 2997   neg     516     na          32     22      0      0      0      0
# 2998   neg    2256     na          48     38      0      0      0      0
# 2999   neg   30800     na           0     na      0      0      0      0
#
#      ag_002  ...   ee_002  ee_003  ee_004  ee_005  ee_006  ee_007  ee_008  \
# ...

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6000 entries, 0 to 2999
# Columns: 171 entries, class to eg_000
# dtypes: int64(1), object(170)
# memory usage: 7.9+ MB

# %%
df_merged.describe(include="all").transpose()
# Out:
#          count unique  top  freq          mean            std  min    25%  \
# class     6000      2  neg  5894           NaN            NaN  NaN    NaN
# aa_000  6000.0    NaN  NaN   NaN  58966.699667  138080.612196  0.0  964.0
# ab_000    6000     10   na  4644           NaN            NaN  NaN    NaN
# ac_000    6000    886    0   815           NaN            NaN  NaN    NaN
# ad_000    6000    840   na  1469           NaN            NaN  NaN    NaN
# ...        ...    ...  ...   ...           ...            ...  ...    ...
# ee_007    6000   4251    0   769           NaN            NaN  NaN    NaN
# ee_008    6000   3508    0  1666           NaN            NaN  NaN    NaN
# ee_009    6000   1887    0  3126           NaN            NaN  NaN    NaN
# ef_000    6000      7    0  5690           NaN            NaN  NaN    NaN
# eg_000    6000     21    0  5661           NaN            NaN  NaN    NaN
#
#             50%      75%        max
# class       NaN      NaN        NaN
# ...

# %%
df_merged=df_merged.reset_index()
df_merged=df_merged.drop(labels=["index"], axis=1)

# %%
from sys import exc_info
from os.path import split
def test():
    x, y, exc_tb = exc_info()
    filename = split(exc_tb.tb_frame.f_code.co_filename)[1]
    print(x, y, e, filename)
    
test()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [60], in <cell line: 8>()
#       5     filename = split(exc_tb.tb_frame.f_code.co_filename)[1]
#       6     print(x, y, e, filename)
# ----> 8 test()
#
# Input In [60], in test()
#       3 def test():
#       4     x, y, exc_tb = exc_info()
# ----> 5     filename = split(exc_tb.tb_frame.f_code.co_filename)[1]
#       6     print(x, y, e, filename)
#
# AttributeError: 'NoneType' object has no attribute 'tb_frame'

# %%
datetime.now().strftime('%Y-%m-%d %H:%M:%S:%f')
# Out:
# '2022-09-21 09:42:01:966189'
